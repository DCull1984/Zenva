# %%
#2 Design; 
#Create a mock drawing of planets to get an estimate of the sizes needed for each planet and the spacing required
#e.g. Radius = 60, 20, 40, 30
#     Distance = 100, 80, 90 etc.

#Steps needed; (Flow Chart, Part 1)
 #A Set background to black, 
 #B Change turtle colour to Orange, 
 #C Draw and fill circle with a radius of 60
 #D Move forwards 100 pixels
 #E Set Turtle colour to Gray
 #F Draw and fill circle with a radius of 20
 #G Move forwards 80 pixels
 #H Set turtle colour to Red
 #I Draw and fill circle with a radius of 40
 #J Move forwards 90 pixels
 #K Set turtle colour to Green
 #L Draw and fill circle with a radius of 30

#Pseudo Code (Part 2);
 #Set background colour to black

 #Set turtle colour to Orange

 #Begin fill
 #Draw circle
 #End fill

 #Lift pen up
 #Move forwards
 #Put pen down

 #Set turtle colour to Gray

 #Begin fill
 #Draw circle
 #End fill

 #Lift pen up
 #Move forwards
 #Put pen down

 #Set turtle colour to Red

 #Begin fill
 #Draw circle
 #End fill

 #Lift pen up
 #Move forwards
 #Put pen down

 #Set turtle colour to Green

 #Begin fill
 #Draw circle
 #End fill

 #Lift pen up
 #Move forwards
 #Put pen down
